# %%
from datasets import load_dataset
from token_access import TOKEN

# %%
dataset = load_dataset("Metacreation/GigaMIDI", token=TOKEN)
# Out:
# train.parquet:   0%|          | 0.00/4.81G [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 dataset = load_dataset("Metacreation/GigaMIDI", token=TOKEN)
#
# File ~\Documents\GitHub\Music_generation_LSTM\.venv\Lib\site-packages\datasets\load.py:2083, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
#    2080     return builder_instance.as_streaming_dataset(split=split)
#    2082 # Download and prepare data
# -> 2083 builder_instance.download_and_prepare(
#    2084     download_config=download_config,
#    2085     download_mode=download_mode,
#    2086     verification_mode=verification_mode,
#    2087     num_proc=num_proc,
# ...
